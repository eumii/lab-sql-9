# %%
import pandas as pd
import numpy as np

import pymysql
from sqlalchemy import create_engine

from getpass import getpass

# %%
password = getpass()

# %%
connection_string = 'mysql+pymysql://root:'+password+'@localhost/sakila'
engine = create_engine(connection_string)

# %%
data1 = pd.read_sql_query("SELECT COUNT(distinct(last_name)) FROM actor", engine)
data1.head()
# Out:
#    COUNT(distinct(last_name))
# 0                         121

# %%
data2 =pd.read_sql_query("SELECT *, monthname(rental_date) AS month, DAYNAME(rental_date) AS weekday, CASE WHEN DAYNAME(rental_date) IN ('Saturday', 'Sunday') THEN ('Week-end') ELSE 'Week-day' END AS day_type  FROM rental", engine)
data2.head()
# Out:
#    rental_id         rental_date  inventory_id  customer_id  \
# 0          1 2005-05-24 22:53:30           367          130
# 1          2 2005-05-24 22:54:33          1525          459
# 2          3 2005-05-24 23:03:39          1711          408
# 3          4 2005-05-24 23:04:41          2452          333
# 4          5 2005-05-24 23:05:21          2079          222
#
#           return_date  staff_id         last_update month  weekday  day_type
# 0 2005-05-26 22:04:30         1 2006-02-15 21:30:53   May  Tuesday  Week-day
# 1 2005-05-28 19:40:33         1 2006-02-15 21:30:53   May  Tuesday  Week-day
# 2 2005-06-01 22:12:39         1 2006-02-15 21:30:53   May  Tuesday  Week-day
# 3 2005-06-03 01:43:41         2 2006-02-15 21:30:53   May  Tuesday  Week-day
# 4 2005-06-02 04:33:21         1 2006-02-15 21:30:53   May  Tuesday  Week-day

# %%
data3 = pd.read_sql_query(("SELECT * \
FROM film \
WHERE title LIKE '%%ARMAGEDDON%%'"), engine)
data3.head(60)
# Out:
#    film_id                  title  \
# 0       39        ARMAGEDDON LOST
# 1      507    LADYBUGS ARMAGEDDON
# 2      571       METAL ARMAGEDDON
# 3      598    MOSQUITO ARMAGEDDON
# 4      838  STAGECOACH ARMAGEDDON
# 5      844      STEERS ARMAGEDDON
#
#                                          description  release_year  \
# 0  A Fast-Paced Tale of a Boat And a Teacher who ...          2006
# 1  A Fateful Reflection of a Dog And a Mad Scient...          2006
# 2  A Thrilling Display of a Lumberjack And a Croc...          2006
# 3  A Thoughtful Character Study of a Waitress And...          2006
# 4  A Touching Display of a Pioneer And a Butler w...          2006
# 5  A Stunning Character Study of a Car And a Girl...          2006
#
#    language_id original_language_id  rental_duration  rental_rate  length  \
# 0            1                 None                5         0.99      99
# 1            1                 None                4         0.99     113
# ...

# %%
data4 = pd.read_sql_query(("SELECT * \
FROM film \
ORDER BY length desc \
LIMIT 10"), engine)

display(data4)
# Out:
#    film_id               title  \
# 0      817  SOLDIERS EVOLUTION
# 1      872   SWEET BROTHERHOOD
# 2      141       CHICAGO NORTH
# 3      991        WORST BANGER
# 4      349         GANGS PRIDE
# 5      212      DARN FORRESTER
# 6      426           HOME PITY
# 7      609       MUSCLE BRIGHT
# 8      182      CONTROL ANTHEM
# 9      690        POND SEATTLE
#
#                                          description  release_year  \
# 0  A Lacklusture Panorama of a A Shark And a Pion...          2006
# 1  A Unbelieveable Epistle of a Sumo Wrestler And...          2006
# 2  A Fateful Yarn of a Mad Cow And a Waitress who...          2006
# 3  A Thrilling Drama of a Madman And a Dentist wh...          2006
# 4  A Taut Character Study of a Woman And a A Shar...          2006
# 5  A Fateful Story of a A Shark And a Explorer wh...          2006
# 6  A Touching Panorama of a Man And a Secret Agen...          2006
# 7  A Stunning Panorama of a Sumo Wrestler And a H...          2006
# ...

# %%
query5 = 'SELECT special_features, COUNT(special_features) AS "films w/ BTS" \
FROM film \
where special_features like "Behind the scenes" \
ORDER BY special_features'

data5 = pd.read_sql_query(query5, engine)
data5
# Out:
#     special_features  films w/ BTS
# 0  Behind the Scenes            70

# %%
query6 = 'SELECT avg(length) as avgl, rating \
FROM film \
GROUP BY rating \
HAVING avgl > 120'

data6 = pd.read_sql_query(query6, engine)
data6
# Out:
#        avgl rating
# 0  120.4439  PG-13

# %%
data7 = pd.read_sql_query(('SELECT length,	title, \
RANK () OVER ( ORDER BY length DESC) AS "rank" \
FROM film \
WHERE length IS NOT NULL AND length != 0'), engine)

data7
# Out:
#      length                title  rank
# 0       185        CHICAGO NORTH     1
# 1       185       CONTROL ANTHEM     1
# 2       185       DARN FORRESTER     1
# 3       185          GANGS PRIDE     1
# 4       185            HOME PITY     1
# ..      ...                  ...   ...
# 995      46         ALIEN CENTER   996
# 996      46            IRON MOON   996
# 997      46        KWAI HOMEWARD   996
# 998      46     LABYRINTH LEAGUE   996
# 999      46  RIDGEMONT SUBMARINE   996
#
# [1000 rows x 3 columns]
